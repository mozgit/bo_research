# %%
import matplotlib.pyplot as plt
import numpy as np
from benchmarking_framework import BenchmarkFramework
from benchmarking_framework.algorithms import RandomSearch, BayesianOptimization
from benchmarking_framework.benchmarks import quadratic_hyperplane_domain, quadratic_hyperplane_problem
import logging
# Define the domains

framework = BenchmarkFramework(problems=[quadratic_hyperplane_problem],
                                                            algorithms = [
                                                                                  RandomSearch(), 
                                                                                   BayesianOptimization(quadratic_hyperplane_domain),
                                                                          ], steps=10, directory="results", overwrite=True, verbosity=logging.ERROR )

framework.run_parallel(10)
# Out:
# /Users/ilya.komarov/dev/bo_research/venv/lib/python3.9/site-packages/botorch/models/utils/assorted.py:202: InputDataWarning: Input data is not standardized (mean = tensor([0.0588], dtype=torch.float64), std = tensor([0.0432], dtype=torch.float64)). Please consider scaling the input to zero mean and unit variance.
#   warnings.warn(msg, InputDataWarning)
# /Users/ilya.komarov/dev/bo_research/venv/lib/python3.9/site-packages/botorch/models/utils/assorted.py:202: InputDataWarning: Input data is not standardized (mean = tensor([0.0849], dtype=torch.float64), std = tensor([0.0385], dtype=torch.float64)). Please consider scaling the input to zero mean and unit variance.
#   warnings.warn(msg, InputDataWarning)
# ...

# %%
from benchmarking_framework.utils.post_processing import load_results, plot_results, plot_time_stats
base_directory = "results/Quadratic Hyperplane"
results = load_results(base_directory)
plot_results(results)
plot_time_stats(results)
